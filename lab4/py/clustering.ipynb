# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_file, show
from bokeh.charts import Scatter, output_file, show
from bokeh.io import output_notebook

# %%
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']

# %%
df = pd.read_csv('data/iris.csv', header=0, names=names)

# %%
df
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 15            5.7          4.4           1.5          0.4     Iris-setosa
# 16            5.4          3.9           1.3          0.4     Iris-setosa
# 17            5.1          3.5           1.4          0.3     Iris-setosa
# 18            5.7          3.8           1.7          0.3     Iris-setosa
# 19            5.1          3.8           1.5          0.3     Iris-setosa
# 20            5.4          3.4           1.7          0.2     Iris-setosa
# 21            5.1          3.7           1.5          0.4     Iris-setosa
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 23            5.1          3.3           1.7          0.5     Iris-setosa
# 24            4.8          3.4           1.9          0.2     Iris-setosa
# 25            5.0          3.0           1.6          0.2     Iris-setosa
# 26            5.0          3.4           1.6          0.4     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 123           6.3          2.7           4.9          1.8  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 125           7.2          3.2           6.0          1.8  Iris-virginica
# 126           6.2          2.8           4.8          1.8  Iris-virginica
# 127           6.1          3.0           4.9          1.8  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 129           7.2          3.0           5.8          1.6  Iris-virginica
# 130           7.4          2.8           6.1          1.9  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 133           6.3          2.8           5.1          1.5  Iris-virginica
# 134           6.1          2.6           5.6          1.4  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class'], dtype='object')

# %%
# create a scatter chart
p = Scatter(df, x='sepal-length', y='sepal-width', color='class')

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="12b20c1c-4304-4c44-9acc-2c82ded22829">Loading BokehJS ...</span>
#     </div>

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="94c99cb6-6c00-449a-99ac-4e5444c85e75"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("94c99cb6-6c00-449a-99ac-4e5444c85e75");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("94c99cb6-6c00-449a-99ac-4e5444c85e75");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '94c99cb6-6c00-449a-99ac-4e5444c85e75' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f8f0164-12ed-4a93-846c-3afcf4deaa78":{"roots":{"references":[{"attributes":{"plot":{"id":"29cef4c6-16af-4f8f-bb42-6ea7f2c23d51","subtype":"Chart","type":"Plot"}},"id":"4cc1c6c6-0746-49ba-b132-345f40eeb0c2","type":"HelpTool"},{"attributes":{"data_source":{"id":"fd17ec48-70e4-458d-af2a-a6abf985190d","type":"ColumnDataSource"},"glyph":{"id":"5f60683d-33b1-46a1-876d-66a380866039","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"89ef30ae-a09a-47ac-b017-b3ff8218c91b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"470da502-f4ee-4988-ab05-3fc37acc1e73","type":"ColumnDataSource"},"glyph":{"id":"7cab521a-8074-45bb-a2f7-ac4841fd5db9","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"f07fd4a6-0483-4e99-bb72-404f9646351e","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"53c167af-0991-4c7d-ad72-875a3bf5eb6b","type":"PanTool"},{"id":"6760701e-b907-4b68-9d99-96e3db831364","type":"WheelZoomTool"},{"id":"d1093e55-3fd2-410c-a474-78a9266da342","type":"BoxZoomTool"},{"id":"607f51fa-04d3-458c-bbc6-65441663deb3","type":"SaveTool"},{"id":"cce7a72f-3c78-4eb5-98e9-741785d386b6","type":"ResetTool"},{"id":"4cc1c6c6-0746-49ba-b132-345f40eeb0c2","type":"HelpTool"}]},"id":"75cc4d8e-2538-4a09-b178-05b7fc42d040","type":"Toolbar"},{"attributes":{"plot":{"id":"29cef4c6-16af-4f8f-bb42-6ea7f2c23d51","subtype":"Chart","type":"Plot"}},"id":"cce7a72f-3c78-4eb5-98e9-741785d386b6","type":"ResetTool"},{"attributes":{"label":{"value":"Iris-virginica"},"renderers":[{"id":"89ef30ae-a09a-47ac-b017-b3ff8218c91b","type":"GlyphRenderer"}]},"id":"afc83940-c9ab-4edd-bce5-03550438b2ae","type":"LegendItem"},{"attributes":{"callback":null,"end":4.640000000000001,"start":1.76},"id":"c1de939e-ed56-4c98-bcbd-5146e47b3d83","type":"Range1d"},{"attributes":{},"id":"2db84c54-14ad-4721-a704-814c17f73ec2","type":"BasicTickFormatter"},{"attributes":{},"id":"d0df8dd9-0fec-4561-80c7-1ab46e5369d4","type":"ToolEvents"},{"attributes":{"label":{"value":"Iris-versicolor"},"renderers":[{"id":"f07fd4a6-0483-4e99-bb72-404f9646351e","type":"GlyphRenderer"}]},"id":"d5d12a0b-4400-4e60-b889-12a57f5dca87","type":"LegendItem"},{"attributes":{"plot":{"id":"29cef4c6-16af-4f8f-bb42-6ea7f2c23d51","subtype":"Chart","type":"Plot"}},"id":"6760701e-b907-4b68-9d99-96e3db831364","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"},{"class":"Iris-virginica"}],"class":["Iris-virginica","Iris-virginica","Iris-virginica","Iris-virginica","Iris-virginica","Iris-virginica","Iris-virginica","Iris-virginica","Iris-virginica","I ...
